# %%
# !pip install torch torchvision
# Out:
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/113.8 MB 4.8 MB/s eta 0:00:24
#    ---------------------------------------- 1.3/113.8 MB 4.8 MB/s eta 0:00:24
#     --------------------------------------- 2.6/113.8 MB 5.0 MB/s eta 0:00:23
#    - -------------------------------------- 3.7/113.8 MB 5.0 MB/s eta 0:00:22
#    - -------------------------------------- 4.7/113.8 MB 5.1 MB/s eta 0:00:22
#    -- ------------------------------------- 6.0/113.8 MB 5.1 MB/s eta 0:00:21
#    -- ------------------------------------- 7.1/113.8 MB 5.2 MB/s eta 0:00:21
#    -- ------------------------------------- 8.4/113.8 MB 5.3 MB/s eta 0:00:21
#    --- ------------------------------------ 9.4/113.8 MB 5.3 MB/s eta 0:00:20
#    --- ------------------------------------ 10.7/113.8 MB 5.3 MB/s eta 0:00:20
#    ---- ----------------------------------- 11.8/113.8 MB 5.4 MB/s eta 0:00:19
# ...

# %%
import torch
import numpy as np

# %%
# pytorch datatypes -> tensors

# %%
torch.tensor([10,20])
# Out:
# tensor([10, 20])

# %%
scalar = torch.tensor(10)

# %%
scalar
# Out:
# tensor(10)

# %%
type(scalar)
# Out:
# torch.Tensor

# %%
 scalar.dim()
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
scalar.item()
# Out:
# 10

# %%
numpy_int = np.int32(10)

# %%
scalar_from_np = torch.tensor(numpy_int)

# %%
scalar_from_np
# Out:
# tensor(10, dtype=torch.int32)

# %%
scalar.dtype
# Out:
# torch.int64

# %%
new_scalar = torch.tensor(25,dtype=torch.int32)

# %%
new_scalar
# Out:
# tensor(25, dtype=torch.int32)

# %%
# vectors

# %%
vector = torch.tensor([2,3])

# %%
vector.dim()
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
# dim -> dimension
# shape -> count of variable in dimensions
